# %% [markdown]
# # **What is Pandas?**
#
# Pandas is an open-source Python library that offers various data structures and operations for manipulating data.

# %%
# !pip install pandas

# %%
import pandas as pd

# %% [markdown]
# ### What Can Pandas Do?
# 1. Is there a correlation between two or more columns?
# 2. What is average value?
# 3. Max value?
# 4. Min value?

# %% [markdown]
# ### Why Pandas?
# 1. Manage and explore data.
# 2. Handle missing data
# 3. Clean up data
# 4. Multiple file formats
# 5. Data visualization

# %% [markdown]
# ### The two main data structures in Pandas are
# 1. Series - A one-dimensional labelled array capable of holding data of any type (integer, string, float, python objects).
# 2. Dataframe - A Data frame is a two-dimensional data structure, i.e., data is aligned in a tabular fashion in rows and columns.
# ![Series_DataFrame.png](attachment:Series_DataFrame.png)

# %% [markdown]
# ## Creating a series from list

# %%
l = ["one", "two", "three"]
l
# Out:
# ['one', 'two', 'three']

# %%
tuple(l)
# Out:
# ('one', 'two', 'three')

# %%
ser = pd.Series(l)
ser
# Out:
# 0      one
# 1      two
# 2    three
# dtype: object

# %%
type(ser)
# Out:
# pandas.core.series.Series

# %% [markdown]
# ## Creating a dataframe from list

# %%
df = pd.DataFrame(l)
df
# Out:
#        0
# 0    one
# 1    two
# 2  three

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
pd.DataFrame([['one', 'two', 'three'], ['four', 'five', 'six'], ['seven', 'eight', 'nine']])
# Out:
#        0      1      2
# 0    one    two  three
# 1   four   five    six
# 2  seven  eight   nine

# %% [markdown]
# * Note: It automatically assigns row index and column index

# %% [markdown]
# ## Creating a dataframe from dictionary

# %%
d = {
    "n": [1, 2, 3],
    "d": ["Sunday", "Monday", "Tuesday"],
    "c": ["red", "blue", "green"]
}
df = pd.DataFrame(d)
df
# Out:
#    n        d      c
# 0  1   Sunday    red
# 1  2   Monday   blue
# 2  3  Tuesday  green

# %% [markdown]
# * Note: Keys becomes the column name

# %%
d1 = {"Fruits": 21, "Vegetables":31}
pd.DataFrame(d1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-9581bf4717d6> in <module>
#       1 d1 = {"Fruits": 21, "Vegetables":31}
# ----> 2 pd.DataFrame(d1)
#
# D:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     527
#     528         elif isinstance(data, dict):
# --> 529             mgr = init_dict(data, index, columns, dtype=dtype)
#     530         elif isinstance(data, ma.MaskedArray):
#     531             import numpy.ma.mrecords as mrecords
#
# D:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals\construction.py in init_dict(data, index, columns, dtype)
#     285             arr if not is_datetime64tz_dtype(arr) else arr.copy() for arr in arrays
#     286         ]
# --> 287     return arrays_to_mgr(arrays, data_names, index, columns, dtype=dtype)
#     288
#     289
#
# D:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals\construction.py in arrays_to_mgr(arrays, arr_names, index, columns, dtype, verify_integrity)
#      78         # figure out the index, if necessary
#      79         if index is None:
# ---> 80             index = extract_index(arrays)
#      81         else:
#      82             index = ensure_index(index)
#
# D:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals\construction.py in extract_index(data)
#     389
#     390         if not indexes and not raw_lengths:
# --> 391             raise ValueError("If using all scalar values, you must pass an index")
#     392
#     393         if have_series:
#
# ValueError: If using all scalar values, you must pass an index

# %%
d1 = {"Fruits": [21], "Vegetables": [31]}
pd.DataFrame(d1)
# Out:
#    Fruits  Vegetables
# 0      21          31

# %% [markdown]
# * Make sure always the values are specified as an ordered sequence .i.e. list or tuples

# %% [markdown]
# ### Specifying custom row and column name

# %%
df
# Out:
#    n        d      c
# 0  1   Sunday    red
# 1  2   Monday   blue
# 2  3  Tuesday  green

# %%
df.rename(index = {0: "Row1", 1: "Row2"})
# Out:
#       n        d      c
# Row1  1   Sunday    red
# Row2  2   Monday   blue
# 2     3  Tuesday  green

# %%
df
# Out:
#    n        d      c
# 0  1   Sunday    red
# 1  2   Monday   blue
# 2  3  Tuesday  green

# %%
df.columns
# Out:
# Index(['n', 'd', 'c'], dtype='object')

# %%
df.rename(columns = {'n': "Col1", 'd': "Col2", 'c': "Col3"}, inplace=True)

# %%
df
# Out:
#    Col1     Col2   Col3
# 0     1   Sunday    red
# 1     2   Monday   blue
# 2     3  Tuesday  green

# %%
df.dtypes
# Out:
# Col1     int64
# Col2    object
# Col3    object
# dtype: object

# %%
df.transpose()
# Out:
#            0       1        2
# Col1       1       2        3
# Col2  Sunday  Monday  Tuesday
# Col3     red    blue    green

# %%
df.T
# Out:
#            0       1        2
# Col1       1       2        3
# Col2  Sunday  Monday  Tuesday
# Col3     red    blue    green

# %%
df
# Out:
#    Col1     Col2   Col3
# 0     1   Sunday    red
# 1     2   Monday   blue
# 2     3  Tuesday  green

# %% [markdown]
# ## Load data from CSV

# %%
pd.read_csv("airtravel.csv")
# Out:
#    Month   "1958"   "1959"   "1960"
# 0    JAN      340      360      417
# 1    FEB      318      342      391
# 2    MAR      362      406      419
# 3    APR      348      396      461
# 4    MAY      363      420      472
# 5    JUN      435      472      535
# 6    JUL      491      548      622
# 7    AUG      505      559      606
# 8    SEP      404      463      508
# 9    OCT      359      407      461
# 10   NOV      310      362      390
# 11   DEC      337      405      432

# %%
pd.read_csv(r"Resource\airtravel2.csv", delimiter='|')
# Out:
#    Month   "1958"   "1959"   "1960"
# 0    JAN      340      360      417
# 1    FEB      318      342      391
# 2    MAR      362      406      419
# 3    APR      348      396      461
# 4    MAY      363      420      472
# 5    JUN      435      472      535
# 6    JUL      491      548      622
# 7    AUG      505      559      606
# 8    SEP      404      463      508
# 9    OCT      359      407      461
# 10   NOV      310      362      390
# 11   DEC      337      405      432

# %%
pd.read_csv("https://raw.githubusercontent.com/Opensourcefordatascience/Data-sets/master/blood_pressure.csv")
# Out:
#      patient     sex agegrp  bp_before  bp_after
# 0          1    Male  30-45        143       153
# 1          2    Male  30-45        163       170
# 2          3    Male  30-45        153       168
# 3          4    Male  30-45        153       142
# 4          5    Male  30-45        146       141
# ..       ...     ...    ...        ...       ...
# 115      116  Female    60+        152       152
# 116      117  Female    60+        161       152
# 117      118  Female    60+        165       174
# 118      119  Female    60+        149       151
# 119      120  Female    60+        185       163
#
# [120 rows x 5 columns]

# %%
pd.read_csv("https://raw.githubusercontent.com/Opensourcefordatascience/Data-sets/master/blood_pressure.csv", index_col= 0)
# Out:
#             sex agegrp  bp_before  bp_after
# patient
# 1          Male  30-45        143       153
# 2          Male  30-45        163       170
# 3          Male  30-45        153       168
# 4          Male  30-45        153       142
# 5          Male  30-45        146       141
# ...         ...    ...        ...       ...
# 116      Female    60+        152       152
# 117      Female    60+        161       152
# 118      Female    60+        165       174
# 119      Female    60+        149       151
# 120      Female    60+        185       163
#
# [120 rows x 4 columns]

# %% [markdown]
# ## Read data from excel

# %%
pd.read_excel(r"Resource\ir211wk12sample.xls")
# Out:
#     OrderDate   Region       Rep     Item      Units   Unit Cost        Total  \
# 0  2014-09-01  Central     Smith     Desk   2.000000  125.000000   250.000000
# 1  2015-06-17  Central    Kivell     Desk   5.000000  125.000000   625.000000
# 2  2015-09-10  Central      Gill   Pencil   7.000000    1.290000     9.030000
# 3  2015-11-17  Central   Jardine   Binder  11.000000    4.990000    54.890000
# 4  2015-10-31  Central   Andrews   Pencil  14.000000    1.290000    18.060000
# 5  2014-02-26  Central      Gill      Pen  27.000000   19.990000   539.730000
# 6  2014-10-05  Central    Morgan   Binder  28.000000    8.990000   251.720000
# 7  2015-12-21  Central   Andrews   Binder  28.000000    4.990000   139.720000
# 8  2014-02-09  Central   Jardine   Pencil  36.000000    4.990000   179.640000
# 9  2015-08-07  Central    Kivell  Pen Set  42.000000   23.950000  1005.900000
# 10 2015-01-15  Central      Gill   Binder  46.000000    8.990000   413.540000
# 11 2014-01-23  Central    Kivell   Binder  50.000000   19.990000   999.500000
# 12 2015-03-24  Central   Jardine  Pen Set  50.000000    4.990000   249.500000
# 13 2015-05-14  Central      Gill   Pencil  53.000000    1.290000    68.370000
# 14 2015-07-21  Central    Morgan  Pen Set  55.000000   12.490000   686.950000
# 15 2015-04-10  Central   Andrews   Pencil  66.000000    1.990000   131.340000
# 16 2014-12-12  Central     Smith   Pencil  67.000000    1.290000    86.430000
# 17 2014-04-18  Central   Andrews   Pencil  75.000000    1.990000   149.250000
# 18 2015-05-31  Central      Gill   Binder  80.000000    8.990000   719.200000
# 19 2015-02-01  Central     Smith   Binder  87.000000   15.000000  1305.000000
# 20 2014-05-05  Central   Jardine   Pencil  90.000000    4.990000   449.100000
# 21 2014-06-25  Central    Morgan   Pencil  90.000000    4.990000   449.100000
# 22 2015-12-04  Central   Jardine   Binder  94.000000   19.990000  1879.060000
# 23 2014-11-25  Central    Kivell  Pen Set  96.000000    4.990000   479.040000
# 24 2015-02-18     East     Jones   Binder   4.000000    4.990000    19.960000
# 25 2014-11-08     East    Parent      Pen  15.000000   19.990000   299.850000
# 26 2014-09-18     East     Jones  Pen Set  16.000000   15.990000   255.840000
# 27 2014-07-12     East    Howard   Binder  29.000000    1.990000    57.710000
# 28 2014-08-15     East     Jones   Pencil  35.000000    4.990000   174.650000
# 29 2014-04-01     East     Jones   Binder  60.000000    4.990000   299.400000
# 30 2014-06-08     East     Jones   Binder  60.000000    8.990000   539.400000
# 31 2015-07-04     East     Jones  Pen Set  62.000000    4.990000   309.380000
# 32 2014-10-22     East     Jones      Pen  64.000000    8.990000   575.360000
# 33 2014-12-29     East    Parent  Pen Set  74.000000   15.990000  1183.260000
# 34 2014-07-29     East    Parent   Binder  81.000000   19.990000  1619.190000
# 35 2014-01-06     East     Jones   Pencil  95.000000    1.990000   189.050000
# 36 2015-04-27     East    Howard      Pen  96.000000    4.990000   479.040000
# 37 2015-08-24     West   Sorvino     Desk   3.000000  275.000000   825.000000
# 38 2015-03-07     West   Sorvino   Binder   7.000000   19.990000   139.930000
# 39 2014-05-22     West  Thompson   Pencil  32.000000    1.990000    63.680000
# 40 2014-03-15     West   Sorvino   Pencil  56.000000    2.990000   167.440000
# 41 2015-10-14     West  Thompson   Binder  57.000000   19.990000  1139.430000
# 42 2015-09-27     West   Sorvino      Pen  76.000000    1.990000   151.240000
# 43        NaT      NaN       NaN      NaN        NaN         NaN          NaN
# 44        NaT      NaN      Mean      NaN  49.325581   20.308605   456.462326
# 45        NaT      NaN    Median      NaN  53.000000    4.990000   299.400000
# 46        NaT      NaN      Mode      NaN   7.000000    4.990000   449.100000
#
#     Unnamed: 7  Bins  Frequency Intervals  Unnamed: 11 Item Type  Frequency.1  \
# 0          NaN   9.0        6.0       0-9          NaN    Pencil         13.0
# 1          NaN  19.0        4.0     10-19          NaN    Binder         15.0
# 2          NaN  29.0        4.0     20-29          NaN       Pen          5.0
# 3          NaN  39.0        3.0     30-39          NaN   Pen Set          7.0
# 4          NaN  49.0        2.0     40-49          NaN      Desk          3.0
# 5          NaN  59.0        6.0     50-59          NaN       NaN         43.0
# 6          NaN  69.0        6.0     60-69          NaN       NaN          NaN
# 7          NaN  79.0        3.0     70-79          NaN       NaN          NaN
# 8          NaN  89.0        3.0     80-89          NaN     10-19          NaN
# 9          NaN  99.0        6.0     90-99          NaN       NaN          NaN
# 10         NaN   NaN        0.0      100+          NaN       NaN          NaN
# 11         NaN   NaN        NaN       NaN          NaN       NaN          NaN
# 12         NaN   NaN        NaN       NaN          NaN       NaN          NaN
# 13         NaN   NaN        NaN       NaN          NaN       NaN          NaN
# 14         NaN   NaN        NaN       NaN          NaN       NaN          NaN
# 15         NaN   NaN        NaN       NaN          NaN       NaN          NaN
# 16         NaN   NaN        NaN       NaN          NaN       NaN          NaN
# 17         NaN   NaN        NaN       NaN          NaN       NaN          NaN
# 18         NaN   NaN        NaN       NaN          NaN       NaN          NaN
# 19         NaN   NaN        NaN       NaN          NaN       NaN          NaN
# 20         NaN   NaN        NaN       NaN          NaN       NaN          NaN
# 21         NaN   NaN        NaN       NaN          NaN       NaN          NaN
# 22         NaN   NaN        NaN       NaN          NaN       NaN          NaN
# 23         NaN   NaN        NaN       NaN          NaN       NaN          NaN
# 24         NaN   NaN        NaN       NaN          NaN       NaN          NaN
# 25         NaN   NaN        NaN       NaN          NaN       NaN          NaN
# 26         NaN   NaN        NaN       NaN          NaN       NaN          NaN
# 27         NaN   NaN        NaN       NaN          NaN       NaN          NaN
# 28         NaN   NaN        NaN       NaN          NaN       NaN          NaN
# 29         NaN   NaN        NaN       NaN          NaN       NaN          NaN
# 30         NaN   NaN        NaN       NaN          NaN       NaN          NaN
# 31         NaN   NaN        NaN       NaN          NaN       NaN          NaN
# 32         NaN   NaN        NaN       NaN          NaN       NaN          NaN
# 33         NaN   NaN        NaN       NaN          NaN       NaN          NaN
# 34         NaN   NaN        NaN       NaN          NaN       NaN          NaN
# 35         NaN   NaN        NaN       NaN          NaN       NaN          NaN
# 36         NaN   NaN        NaN       NaN          NaN       NaN          NaN
# 37         NaN   NaN        NaN       NaN          NaN       NaN          NaN
# 38         NaN   NaN        NaN       NaN          NaN       NaN          NaN
# 39         NaN   NaN        NaN       NaN          NaN       NaN          NaN
# 40         NaN   NaN        NaN       NaN          NaN       NaN          NaN
# 41         NaN   NaN        NaN       NaN          NaN       NaN          NaN
# 42         NaN   NaN        NaN       NaN          NaN       NaN          NaN
# 43         NaN   NaN        NaN       NaN          NaN       NaN          NaN
# 44         NaN   NaN        NaN       NaN          NaN       NaN          NaN
# 45         NaN   NaN        NaN       NaN          NaN       NaN          NaN
# 46         NaN   NaN        NaN       NaN          NaN       NaN          NaN
#
#     Rel. Freq   % Freq.
# 0    0.302326  0.302326
# 1    0.348837  0.348837
# 2    0.116279  0.116279
# 3    0.162791  0.162791
# 4    0.069767  0.069767
# 5    1.000000  1.000000
# 6         NaN       NaN
# 7         NaN       NaN
# 8         NaN       NaN
# 9         NaN       NaN
# 10        NaN       NaN
# 11        NaN       NaN
# 12        NaN       NaN
# 13        NaN       NaN
# 14        NaN       NaN
# 15        NaN       NaN
# 16        NaN       NaN
# 17        NaN       NaN
# 18        NaN       NaN
# 19        NaN       NaN
# 20        NaN       NaN
# 21        NaN       NaN
# 22        NaN       NaN
# 23        NaN       NaN
# 24        NaN       NaN
# 25        NaN       NaN
# 26        NaN       NaN
# 27        NaN       NaN
# 28        NaN       NaN
# 29        NaN       NaN
# 30        NaN       NaN
# 31        NaN       NaN
# 32        NaN       NaN
# 33        NaN       NaN
# 34        NaN       NaN
# 35        NaN       NaN
# 36        NaN       NaN
# 37        NaN       NaN
# 38        NaN       NaN
# 39        NaN       NaN
# 40        NaN       NaN
# 41        NaN       NaN
# 42        NaN       NaN
# 43        NaN       NaN
# 44        NaN       NaN
# 45        NaN       NaN
# 46        NaN       NaN

# %%
pd.read_excel(r"Resource\ir211wk12sample.xls", sheet_name=1)
# Out:
#     Unnamed: 0                                Unnamed: 1  \
# 0          NaN                      Contextures Products
# 1          NaN                                       NaN
# 2          NaN                 PivotPower Premium Add-in
# 3          NaN        UserForms for Data Entry ebook Kit
# 4          NaN            Contextures Excel Tools Add-in
# 5          NaN  Data Validation Multi-Select Premium Kit
# 6          NaN   30 Excel Functions in 30 Days eBook Kit
# 7          NaN                                       NaN
# 8          NaN                    Contextures Recommends
# 9          NaN                                       NaN
# 10         NaN       Jon Peltier's Excel Chart Utilities
# 11         NaN                      ExcelUser Dashboards
# 12         NaN                 Xtreme Pivot Table Course
# 13         NaN                    Power Pivot University
# 14         NaN                      Excel Courses Online
# 15         NaN                Chandoo's Excel VBA School
# 16         NaN    Chandoo's Project Management Templates
# 17         NaN                                       NaN
# 18         NaN                  Contextures Sites & News
# 19         NaN                                       NaN
# 20         NaN              Contextures Excel Newsletter
# 21         NaN            Contextures Excel Tips Website
# 22         NaN                    Contextures Excel Blog
# 23         NaN                   Excel Pivot Tables Blog
# 24         NaN       Debra's Pivot Table Books on Amazon
#
#                                            Unnamed: 2
# 0                                                 NaN
# 1                                                 NaN
# 2       Time-saving tools for pivot table power users
# 3                Step by step instructions and videos
# 4   Make instant backups, sort sheets, and many mo...
# 5   Select multiple items from a listbox, to enter...
# 6   Sample workbook and easy to follow user guide ...
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10       Create complex charts with just a few clicks
# 11  Templates and instructions for impressive dash...
# 12    Video training from beginner to advanced topics
# 13     Online course by Power Pivot expert Rob Collie
# 14                     Excel training by Mynda Treacy
# 15  Become awesome in Excel VBA with Chandoo's onl...
# 16  Save time with Chandoo's templates for project...
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20     Weekly Excel tips, tutorials, videos, and news
# 21       Hundreds of tutorials, tips and sample files
# 22   Read the Excel tutorials and share your comments
# 23  Pivot table tutorials and tips, with comments ...
# 24                   Pivot table books for Excel 2007

# %%
file = pd.ExcelFile(r"Resource\ir211wk12sample.xls")
file.sheet_names
# Out:
# ['SalesOrders', 'MyLinks', 'Sheet1']

# %%
pd.read_excel(r"Resource\ir211wk12sample.xls", usecols=[0, 1, 2, 3])
# Out:
#     OrderDate   Region       Rep     Item
# 0  2014-09-01  Central     Smith     Desk
# 1  2015-06-17  Central    Kivell     Desk
# 2  2015-09-10  Central      Gill   Pencil
# 3  2015-11-17  Central   Jardine   Binder
# 4  2015-10-31  Central   Andrews   Pencil
# 5  2014-02-26  Central      Gill      Pen
# 6  2014-10-05  Central    Morgan   Binder
# 7  2015-12-21  Central   Andrews   Binder
# 8  2014-02-09  Central   Jardine   Pencil
# 9  2015-08-07  Central    Kivell  Pen Set
# 10 2015-01-15  Central      Gill   Binder
# 11 2014-01-23  Central    Kivell   Binder
# 12 2015-03-24  Central   Jardine  Pen Set
# 13 2015-05-14  Central      Gill   Pencil
# 14 2015-07-21  Central    Morgan  Pen Set
# 15 2015-04-10  Central   Andrews   Pencil
# 16 2014-12-12  Central     Smith   Pencil
# 17 2014-04-18  Central   Andrews   Pencil
# 18 2015-05-31  Central      Gill   Binder
# 19 2015-02-01  Central     Smith   Binder
# 20 2014-05-05  Central   Jardine   Pencil
# 21 2014-06-25  Central    Morgan   Pencil
# 22 2015-12-04  Central   Jardine   Binder
# 23 2014-11-25  Central    Kivell  Pen Set
# 24 2015-02-18     East     Jones   Binder
# 25 2014-11-08     East    Parent      Pen
# 26 2014-09-18     East     Jones  Pen Set
# 27 2014-07-12     East    Howard   Binder
# 28 2014-08-15     East     Jones   Pencil
# 29 2014-04-01     East     Jones   Binder
# 30 2014-06-08     East     Jones   Binder
# 31 2015-07-04     East     Jones  Pen Set
# 32 2014-10-22     East     Jones      Pen
# 33 2014-12-29     East    Parent  Pen Set
# 34 2014-07-29     East    Parent   Binder
# 35 2014-01-06     East     Jones   Pencil
# 36 2015-04-27     East    Howard      Pen
# 37 2015-08-24     West   Sorvino     Desk
# 38 2015-03-07     West   Sorvino   Binder
# 39 2014-05-22     West  Thompson   Pencil
# 40 2014-03-15     West   Sorvino   Pencil
# 41 2015-10-14     West  Thompson   Binder
# 42 2015-09-27     West   Sorvino      Pen
# 43        NaT      NaN       NaN      NaN
# 44        NaT      NaN      Mean      NaN
# 45        NaT      NaN    Median      NaN
# 46        NaT      NaN      Mode      NaN

# %% [markdown]
# ### Load data from html page

# %%
stock_Prices = pd.read_html("https://www.moneycontrol.com/india/stockpricequote/computers-software/larsentoubroinfotech/LI12")

# %%
stock_Prices
# Out:
# [    BUY    BUY.1     SELL SELL.1
#  0   QTY    PRICE    PRICE    QTY
#  1    12  5887.65  5893.20      3
#  2     1  5887.10  5899.90      9
#  3     1  5886.00  5899.95    148
#  4     1  5881.10  5900.00      1
#  5     2  5880.00  5900.50      3
#  6  1078    Total    Total   1222,
#      BUY    BUY.1     SELL SELL.1
#  0   QTY    PRICE    PRICE    QTY
#  1    12  5887.65  5893.20      3
#  2     1  5887.10  5899.90      9
#  3     1  5886.00  5899.95    148
#  4     1  5881.10  5900.00      1
#  5     2  5880.00  5900.50      3
#  6  1078    Total    Total   1222,
#                  0          1
#  0            Open    6000.00
#  1  Previous Close    6059.75
#  2          Volume  450430.00
#  3    Value (Lacs)   26622.89
#  4         i  VWAP    5901.27
#  5            Beta   0.880.87,
#                0        1
#  0          High  6019.85
#  1           Low  5801.00
#  2      UC Limit  6665.70
#  3      LC Limit  5453.80
#  4  52 Week High  7588.80
#  5   52 Week Low  3525.00,
#                        0       1
#  0               TTM EPS  125.78
#  1                TTM PE   46.99
#  2             Sector PE   36.94
#  3  Book Value Per Share  412.30
#  4                   P/B   14.34
#  5            Face Value    1.00,
#                       0          1
#  0    Mkt Cap (Rs. Cr.)  103613.00
#  1       Dividend Yield       0.68
#  2       20D Avg Volume  317954.00
#  3  20D Avg Delivery(%)      45.94,
#                  0    1
#  0            Open  - -
#  1  Previous Close  - -
#  2          Volume  - -
#  3     Value(lacs)  - -,
#        0    1
#  0  High  - -
#  1   Low  - -
#  2   ATP  - -
#  3  Spot  - -,
#                    0    1
#  0                OI  - -
#  1      OI Chg(Chg%)  - -
#  2          Lot Size  - -
#  3  Contracts Traded  - -,
#                  0    1
#  0     Roll Over %  - -
#  1  Roll Over Cost  - -
#  2            MWPL  - -,
#                  0   1
#  0            Open  --
#  1  Previous Close  --
#  2          Volume  --
#  3    Value (lacs)  --,
#        0   1
#  0  High  --
#  1   Low  --
#  2   ATP  --
#  3  Spot  --,
#                    0   1
#  0                OI  --
#  1      OI Chg(Chg%)  --
#  2          Lot Size  --
#  3  Contracts Traded  --,
#       0   1
#  0  PCR  --,
#                              0   1
#  0             Moving Averages  --
#  1        Technical Indicators  --
#  2  Moving Averages Crossovers  --,
#          Type   R1   R2   R3   PP   S1   S2   S3
#  0    Classic  - -  - -  - -  - -  - -  - -  - -
#  1  Fibonacci  - -  - -  - -  - -  - -  - -  - -
#  2  Camarilla  - -  - -  - -  - -  - -  - -  - -,
#      0    1           2   3    4
#  0  R1  - -  Pivot  - -  S1  - -
#  1  R2  - -  Pivot  - -  S2  - -
#  2  R3  - -  Pivot  - -  S3  - -,
#     Days SMA  EMA
#  0     5      - -
#  1    10      - -
#  2    20      - -
#  3    50      - -
#  4   100      - -
#  5   200      - -,
#                              0   1
#  0             Moving Averages  --
#  1        Technical Indicators  --
#  2  Moving Averages Crossovers  --,
#          Type   R1   R2   R3   PP   S1   S2   S3
#  0    Classic  - -  - -  - -  - -  - -  - -  - -
#  1  Fibonacci  - -  - -  - -  - -  - -  - -  - -
#  2  Camarilla  - -  - -  - -  - -  - -  - -  - -,
#      0    1           2   3    4
#  0  R1  - -  Pivot  - -  S1  - -
#  1  R2  - -  Pivot  - -  S2  - -
#  2  R3  - -  Pivot  - -  S3  - -,
#  Empty DataFrame
#  Columns: [Days, SMA  EMA]
#  Index: [],
#                              0   1
#  0             Moving Averages  --
#  1        Technical Indicators  --
#  2  Moving Averages Crossovers  --,
#          Type   R1   R2   R3   PP   S1   S2   S3
#  0    Classic  - -  - -  - -  - -  - -  - -  - -
#  1  Fibonacci  - -  - -  - -  - -  - -  - -  - -
#  2  Camarilla  - -  - -  - -  - -  - -  - -  - -,
#      0    1           2   3    4
#  0  R1  - -  Pivot  - -  S1  - -
#  1  R2  - -  Pivot  - -  S2  - -
#  2  R3  - -  Pivot  - -  S3  - -,
#  Empty DataFrame
#  Columns: [Days, SMA  EMA]
#  Index: [],
#            0   1    2
#  0    1 Week NaN  --%
#  1   1 Month NaN  --%
#  2  3 Months NaN  --%
#  3       YTD NaN  --%
#  4    1 Year NaN  --%
#  5   3 Years NaN  --%,
#                      0                  1
#  0  Reco Price 5907.00  Target Price 6850,
#             0              1              2
#  0  Qty 49198  Price 6855.15  % Traded 0.03,
#             0              1              2
#  0  Qty 49198  Price 6855.15  % Traded 0.03,
#             0              1              2
#  0  Qty 49198  Price 5983.55  % Traded 0.03,
#             0              1              2
#  0  Qty 49198  Price 5983.55  % Traded 0.03,
#             0           1              2
#  0  Qty 18099  Price 5715  % Traded 0.01,
#             0           1              2
#  0  Qty 18099  Price 5715  % Traded 0.01,
#             0             1              2
#  0  Qty 50583  Price 5750.8  % Traded 0.03,
#             0             1              2
#  0  Qty 50583  Price 5750.8  % Traded 0.03,
#               0              1              2
#  0  Qty 1336965  Price 3190.01  % Traded 0.76,
#               0           1              2
#  0  Qty 1000000  Price 1399  % Traded 0.57,
#               0          1              2
#  0  Qty 1724854  Price 698  % Traded 0.99,
#               0          1              2
#  0  Qty 1724854  Price 698  % Traded 0.99,
#               0             1              2
#  0  Qty 1335000  Price 700.26  % Traded 0.76,
#           0           1              2                  3
#  0  Qty 500  Price 5980  % Traded 0.00  Post Tnx Hold. 0%,
#            0              1              2                     3
#  0  Qty 6500  Price 5957.46  % Traded 0.00  Post Tnx Hold. 0.01%,
#            0           1              2                     3
#  0  Qty 4000  Price 6271  % Traded 0.00  Post Tnx Hold. 0.01%,
#           0           1              2                  3
#  0  Qty 500  Price 6280  % Traded 0.00  Post Tnx Hold. 0%,
#            0           1              2                     3
#  0  Qty 1000  Price 6290  % Traded 0.00  Post Tnx Hold. 0.01%,
#           0              1              2                  3
#  0  Qty 200  Price 6307.38  % Traded 0.00  Post Tnx Hold. 0%,
#  Empty DataFrame
#  Columns: [Date, Agenda]
#  Index: [],
#  Empty DataFrame
#  Columns: [Ex-Date, Type, Dividend (Rs)]
#  Index: [],
#  Empty DataFrame
#  Columns: [Announcement Date, Ex-Bonus, Ratio]
#  Index: [],
#  Empty DataFrame
#  Columns: [Ex-Split, Old FV, New FV]
#  Index: [],
#  Empty DataFrame
#  Columns: [Ex-Right, Ratio, Premium]
#  Index: [],
#  Empty DataFrame
#  Columns: [Date, Agenda]
#  Index: [],
#    Institutional Holder Analysis  Total Number  Change  Total Holding (%)  \
#  0         MF Schemes (Dec 2021)            29       1               4.39
#  1            FII/FPI (Dec 2021)           476      23              12.53
#
#     Change.1
#  0      0.38
#  1     -0.72  ,
#     Company Name    Price  % Chg    MCap(Cr)  TTM PE    P/B  ROE(%)  \
#  0  L&T Infotech  5910.55  -2.46   103613.22   46.99  14.34   26.50
#  1           TCS  3691.10  -0.14  1350942.60   35.25  15.04   42.99
#  2       Infosys  1742.45  -1.36   733003.17   34.09   9.60   25.34
#  3      HCL Tech  1131.15  -0.21   306956.23   27.88   5.11   18.60
#  4         Wipro   558.70  -2.17   306283.26   25.28   5.59   19.66
#
#     1 Yr Perform(%)  Net Profit(Rs.)  Net Sales(Rs.)  Debt to Equity
#  0            38.82             1938           12369            0.01
#  1            13.69            38449          191754            0.02
#  2            22.21            19423          100472            0.00
#  3            12.06            11169           75379            0.06
#  4            29.15            10855           61934            0.12  ]

# %%
type(stock_Prices)
# Out:
# list

# %%
len(stock_Prices)
# Out:
# 55

# %%
stock_Prices[0]
# Out:
#     BUY    BUY.1     SELL SELL.1
# 0   QTY    PRICE    PRICE    QTY
# 1    12  5887.65  5893.20      3
# 2     1  5887.10  5899.90      9
# 3     1  5886.00  5899.95    148
# 4     1  5881.10  5900.00      1
# 5     2  5880.00  5900.50      3
# 6  1078    Total    Total   1222

# %%
stock_Prices[2]
# Out:
#                 0          1
# 0            Open    6000.00
# 1  Previous Close    6059.75
# 2          Volume  450430.00
# 3    Value (Lacs)   26622.89
# 4         i  VWAP    5901.27
# 5            Beta   0.880.87

# %%
stock_Prices[3]
# Out:
#               0        1
# 0          High  6019.85
# 1           Low  5801.00
# 2      UC Limit  6665.70
# 3      LC Limit  5453.80
# 4  52 Week High  7588.80
# 5   52 Week Low  3525.00

# %%
stock_Prices[3].set_index(0)
# Out:
#                     1
# 0
# High          6019.85
# Low           5801.00
# UC Limit      6665.70
# LC Limit      5453.80
# 52 Week High  7588.80
# 52 Week Low   3525.00

# %% [markdown]
# ### Saving dataframe

# %%
anotherdf = pd.read_csv("https://raw.githubusercontent.com/Opensourcefordatascience/Data-sets/master/blood_pressure.csv", index_col= 0)

# %%
anotherdf.to_csv("bloodpressure.csv")

# %%
anotherdf.to_dict(orient='index')
# Out:
# {1: {'sex': 'Male', 'agegrp': '30-45', 'bp_before': 143, 'bp_after': 153},
#  2: {'sex': 'Male', 'agegrp': '30-45', 'bp_before': 163, 'bp_after': 170},
#  3: {'sex': 'Male', 'agegrp': '30-45', 'bp_before': 153, 'bp_after': 168},
#  4: {'sex': 'Male', 'agegrp': '30-45', 'bp_before': 153, 'bp_after': 142},
#  5: {'sex': 'Male', 'agegrp': '30-45', 'bp_before': 146, 'bp_after': 141},
#  6: {'sex': 'Male', 'agegrp': '30-45', 'bp_before': 150, 'bp_after': 147},
#  7: {'sex': 'Male', 'agegrp': '30-45', 'bp_before': 148, 'bp_after': 133},
#  8: {'sex': 'Male', 'agegrp': '30-45', 'bp_before': 153, 'bp_after': 141},
#  9: {'sex': 'Male', 'agegrp': '30-45', 'bp_before': 153, 'bp_after': 131},
#  10: {'sex': 'Male', 'agegrp': '30-45', 'bp_before': 158, 'bp_after': 125},
#  11: {'sex': 'Male', 'agegrp': '30-45', 'bp_before': 149, 'bp_after': 164},
#  12: {'sex': 'Male', 'agegrp': '30-45', 'bp_before': 173, 'bp_after': 159},
#  13: {'sex': 'Male', 'agegrp': '30-45', 'bp_before': 165, 'bp_after': 135},
#  14: {'sex': 'Male', 'agegrp': '30-45', 'bp_before': 145, 'bp_after': 159},
#  15: {'sex': 'Male', 'agegrp': '30-45', 'bp_before': 143, 'bp_after': 153},
#  16: {'sex': 'Male', 'agegrp': '30-45', 'bp_before': 152, 'bp_after': 126},
#  17: {'sex': 'Male', 'agegrp': '30-45', 'bp_before': 141, 'bp_after': 162},
#  18: {'sex': 'Male', 'agegrp': '30-45', 'bp_before': 176, 'bp_after': 134},
#  19: {'sex': 'Male', 'agegrp': '30-45', 'bp_before': 143, 'bp_after': 136},
#  20: {'sex': 'Male', 'agegrp': '30-45', 'bp_before': 162, 'bp_after': 150},
#  21: {'sex': 'Male', 'agegrp': '46-59', 'bp_before': 149, 'bp_after': 168},
#  22: {'sex': 'Male', 'agegrp': '46-59', 'bp_before': 156, 'bp_after': 155},
#  23: {'sex': 'Male', 'agegrp': '46-59', 'bp_before': 151, 'bp_after': 136},
#  24: {'sex': 'Male', 'agegrp': '46-59', 'bp_before': 159, 'bp_after': 132},
#  25: {'sex': 'Male', 'agegrp': '46-59', 'bp_before': 164, 'bp_after': 160},
#  26: {'sex': 'Male', 'agegrp': '46-59', 'bp_before': 154, 'bp_after': 160},
#  27: {'sex': 'Male', 'agegrp': '46-59', 'bp_before': 152, 'bp_after': 136},
#  28: {'sex': 'Male', 'agegrp': '46-59', 'bp_before': 142, 'bp_after': 183},
#  29: {'sex': 'Male', 'agegrp': '46-59', 'bp_before': 162, 'bp_after': 152},
#  30: {'sex': 'Male', 'agegrp': '46-59', 'bp_before': 155, 'bp_after': 162},
#  31: {'sex': 'Male', 'agegrp': '46-59', 'bp_before': 175, 'bp_after': 151},
#  32: {'sex': 'Male', 'agegrp': '46-59', 'bp_before': 184, 'bp_after': 139},
#  33: {'sex': 'Male', 'agegrp': '46-59', 'bp_before': 167, 'bp_after': 175},
#  34: {'sex': 'Male', 'agegrp': '46-59', 'bp_before': 148, 'bp_after': 184},
#  35: {'sex': 'Male', 'agegrp': '46-59', 'bp_before': 170, 'bp_after': 151},
#  36: {'sex': 'Male', 'agegrp': '46-59', 'bp_before': 159, 'bp_after': 171},
#  37: {'sex': 'Male', 'agegrp': '46-59', 'bp_before': 149, 'bp_after': 157},
#  38: {'sex': 'Male', 'agegrp': '46-59', 'bp_before': 140, 'bp_after': 159},
#  39: {'sex': 'Male', 'agegrp': '46-59', 'bp_before': 185, 'bp_after': 140},
#  40: {'sex': 'Male', 'agegrp': '46-59', 'bp_before': 160, 'bp_after': 174},
#  41: {'sex': 'Male', 'agegrp': '60+', 'bp_before': 157, 'bp_after': 167},
#  42: {'sex': 'Male', 'agegrp': '60+', 'bp_before': 158, 'bp_after': 158},
#  43: {'sex': 'Male', 'agegrp': '60+', 'bp_before': 162, 'bp_after': 168},
#  44: {'sex': 'Male', 'agegrp': '60+', 'bp_before': 160, 'bp_after': 159},
#  45: {'sex': 'Male', 'agegrp': '60+', 'bp_before': 180, 'bp_after': 153},
#  46: {'sex': 'Male', 'agegrp': '60+', 'bp_before': 155, 'bp_after': 164},
#  47: {'sex': 'Male', 'agegrp': '60+', 'bp_before': 172, 'bp_after': 169},
#  48: {'sex': 'Male', 'agegrp': '60+', 'bp_before': 157, 'bp_after': 148},
#  49: {'sex': 'Male', 'agegrp': '60+', 'bp_before': 171, 'bp_after': 185},
#  50: {'sex': 'Male', 'agegrp': '60+', 'bp_before': 170, 'bp_after': 163},
#  51: {'sex': 'Male', 'agegrp': '60+', 'bp_before': 175, 'bp_after': 146},
#  52: {'sex': 'Male', 'agegrp': '60+', 'bp_before': 175, 'bp_after': 160},
#  53: {'sex': 'Male', 'agegrp': '60+', 'bp_before': 172, 'bp_after': 175},
#  54: {'sex': 'Male', 'agegrp': '60+', 'bp_before': 173, 'bp_after': 163},
#  55: {'sex': 'Male', 'agegrp': '60+', 'bp_before': 170, 'bp_after': 185},
#  56: {'sex': 'Male', 'agegrp': '60+', 'bp_before': 164, 'bp_after': 146},
#  57: {'sex': 'Male', 'agegrp': '60+', 'bp_before': 147, 'bp_after': 176},
#  58: {'sex': 'Male', 'agegrp': '60+', 'bp_before': 154, 'bp_after': 147},
#  59: {'sex': 'Male', 'agegrp': '60+', 'bp_before': 172, 'bp_after': 161},
#  60: {'sex': 'Male', 'agegrp': '60+', 'bp_before': 162, 'bp_after': 164},
#  61: {'sex': 'Female', 'agegrp': '30-45', 'bp_before': 152, 'bp_after': 149},
#  62: {'sex': 'Female', 'agegrp': '30-45', 'bp_before': 147, 'bp_after': 142},
#  63: {'sex': 'Female', 'agegrp': '30-45', 'bp_before': 144, 'bp_after': 146},
#  64: {'sex': 'Female', 'agegrp': '30-45', 'bp_before': 144, 'bp_after': 138},
#  65: {'sex': 'Female', 'agegrp': '30-45', 'bp_before': 158, 'bp_after': 131},
#  66: {'sex': 'Female', 'agegrp': '30-45', 'bp_before': 147, 'bp_after': 145},
#  67: {'sex': 'Female', 'agegrp': '30-45', 'bp_before': 154, 'bp_after': 134},
#  68: {'sex': 'Female', 'agegrp': '30-45', 'bp_before': 151, 'bp_after': 135},
#  69: {'sex': 'Female', 'agegrp': '30-45', 'bp_before': 149, 'bp_after': 131},
#  70: {'sex': 'Female', 'agegrp': '30-45', 'bp_before': 138, 'bp_after': 135},
#  71: {'sex': 'Female', 'agegrp': '30-45', 'bp_before': 162, 'bp_after': 133},
#  72: {'sex': 'Female', 'agegrp': '30-45', 'bp_before': 157, 'bp_after': 135},
#  73: {'sex': 'Female', 'agegrp': '30-45', 'bp_before': 141, 'bp_after': 168},
#  74: {'sex': 'Female', 'agegrp': '30-45', 'bp_before': 167, 'bp_after': 144},
#  75: {'sex': 'Female', 'agegrp': '30-45', 'bp_before': 147, 'bp_after': 147},
#  76: {'sex': 'Female', 'agegrp': '30-45', 'bp_before': 143, 'bp_after': 151},
#  77: {'sex': 'Female', 'agegrp': '30-45', 'bp_before': 142, 'bp_after': 149},
#  78: {'sex': 'Female', 'agegrp': '30-45', 'bp_before': 166, 'bp_after': 147},
#  79: {'sex': 'Female', 'agegrp': '30-45', 'bp_before': 147, 'bp_after': 149},
#  80: {'sex': 'Female', 'agegrp': '30-45', 'bp_before': 142, 'bp_after': 135},
#  81: {'sex': 'Female', 'agegrp': '46-59', 'bp_before': 157, 'bp_after': 127},
#  82: {'sex': 'Female', 'agegrp': '46-59', 'bp_before': 170, 'bp_after': 150},
#  83: {'sex': 'Female', 'agegrp': '46-59', 'bp_before': 150, 'bp_after': 138},
#  84: {'sex': 'Female', 'agegrp': '46-59', 'bp_before': 150, 'bp_after': 147},
#  85: {'sex': 'Female', 'agegrp': '46-59', 'bp_before': 167, 'bp_after': 157},
#  86: {'sex': 'Female', 'agegrp': '46-59', 'bp_before': 154, 'bp_after': 146},
#  87: {'sex': 'Female', 'agegrp': '46-59', 'bp_before': 143, 'bp_after': 148},
#  88: {'sex': 'Female', 'agegrp': '46-59', 'bp_before': 157, 'bp_after': 136},
#  89: {'sex': 'Female', 'agegrp': '46-59', 'bp_before': 149, 'bp_after': 146},
#  90: {'sex': 'Female', 'agegrp': '46-59', 'bp_before': 161, 'bp_after': 132},
#  91: {'sex': 'Female', 'agegrp': '46-59', 'bp_before': 142, 'bp_after': 145},
#  92: {'sex': 'Female', 'agegrp': '46-59', 'bp_before': 162, 'bp_after': 132},
#  93: {'sex': 'Female', 'agegrp': '46-59', 'bp_before': 144, 'bp_after': 157},
#  94: {'sex': 'Female', 'agegrp': '46-59', 'bp_before': 142, 'bp_after': 140},
#  95: {'sex': 'Female', 'agegrp': '46-59', 'bp_before': 159, 'bp_after': 137},
#  96: {'sex': 'Female', 'agegrp': '46-59', 'bp_before': 140, 'bp_after': 154},
#  97: {'sex': 'Female', 'agegrp': '46-59', 'bp_before': 144, 'bp_after': 169},
#  98: {'sex': 'Female', 'agegrp': '46-59', 'bp_before': 142, 'bp_after': 145},
#  99: {'sex': 'Female', 'agegrp': '46-59', 'bp_before': 145, 'bp_after': 137},
#  100: {'sex': 'Female', 'agegrp': '46-59', 'bp_before': 145, 'bp_after': 143},
#  101: {'sex': 'Female', 'agegrp': '60+', 'bp_before': 168, 'bp_after': 178},
#  102: {'sex': 'Female', 'agegrp': '60+', 'bp_before': 142, 'bp_after': 141},
#  103: {'sex': 'Female', 'agegrp': '60+', 'bp_before': 147, 'bp_after': 149},
#  104: {'sex': 'Female', 'agegrp': '60+', 'bp_before': 148, 'bp_after': 148},
#  105: {'sex': 'Female', 'agegrp': '60+', 'bp_before': 162, 'bp_after': 138},
#  106: {'sex': 'Female', 'agegrp': '60+', 'bp_before': 170, 'bp_after': 143},
#  107: {'sex': 'Female', 'agegrp': '60+', 'bp_before': 173, 'bp_after': 167},
#  108: {'sex': 'Female', 'agegrp': '60+', 'bp_before': 151, 'bp_after': 158},
#  109: {'sex': 'Female', 'agegrp': '60+', 'bp_before': 155, 'bp_after': 152},
#  110: {'sex': 'Female', 'agegrp': '60+', 'bp_before': 163, 'bp_after': 154},
#  111: {'sex': 'Female', 'agegrp': '60+', 'bp_before': 183, 'bp_after': 161},
#  112: {'sex': 'Female', 'agegrp': '60+', 'bp_before': 159, 'bp_after': 143},
#  113: {'sex': 'Female', 'agegrp': '60+', 'bp_before': 148, 'bp_after': 159},
#  114: {'sex': 'Female', 'agegrp': '60+', 'bp_before': 151, 'bp_after': 177},
#  115: {'sex': 'Female', 'agegrp': '60+', 'bp_before': 165, 'bp_after': 142},
#  116: {'sex': 'Female', 'agegrp': '60+', 'bp_before': 152, 'bp_after': 152},
#  117: {'sex': 'Female', 'agegrp': '60+', 'bp_before': 161, 'bp_after': 152},
#  118: {'sex': 'Female', 'agegrp': '60+', 'bp_before': 165, 'bp_after': 174},
#  119: {'sex': 'Female', 'agegrp': '60+', 'bp_before': 149, 'bp_after': 151},
#  120: {'sex': 'Female', 'agegrp': '60+', 'bp_before': 185, 'bp_after': 163}}

# %%
anotherdf.to_html("bloodpressure.html")
