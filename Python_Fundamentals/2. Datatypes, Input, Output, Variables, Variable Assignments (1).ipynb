# %% [markdown]
# ### Datatypes

# %% [markdown]
# Indicates the types of data.
# * str : text
# * int : numeric
# * float : decimal
# * complex : complex number of the form a+ib
# * bool : True or False

# %%
5645

# %%
type(5645)
# Out:
# int

# %%
1.2

# %%
type(1.2)
# Out:
# float

# %%
'I love Python'

# %%
type('I love Python')
# Out:
# str

# %%
type("123543543%#%$#%$^%$^HDHGHJGJ        HJGKHJGJH")
# Out:
# str

# %%
True

# %%
type(False)
# Out:
# bool

# %% [markdown]
# ### Variables

# %% [markdown]
# Place holder to store data.
# <br>Eg: a, name, _num, place123

# %% [markdown]
# ### Variable assignment

# %%
a = 3

# %%
type(a)  # python automatically finds out the type of a variable depending on value assigned
# Out:
# int

# %%
a: int = 2 # we can also mention the type of variable but this is not mandatory

# %%
a
# Out:
# 2

# %%
type(a)
# Out:
# int

# %%
a:int = 'xyz'  # even if we focefully say a is int, if we assign some other data then also python type casts the datatype as per the value

# %%
a
# Out:
# 'xyz'

# %%
type(a)
# Out:
# str

# %%
name = "Python"

# %%
name
# Out:
# 'Python'

# %%
type(name)
# Out:
# str

# %% [markdown]
# ### Multiple variable assignment

# %%
a, b, c = 1, "hello", 3.4

# %%
a
# Out:
# 1

# %%
b
# Out:
# 'hello'

# %%
c
# Out:
# 3.4

# %%
type(c)
# Out:
# float

# %% [markdown]
# ### Input

# %%
a = input("Enter a number: ")
# Out:
# Enter a number: 34

# %%
a  # input() always returns value as a string
# Out:
# '34'

# %%
type(a)
# Out:
# str

# %%
int(a) # its required to explicitily typecast to int if we want an integer
# Out:
# 34

# %%
a = int(input("Enter a number"))
# Out:
# Enter a number50

# %%
type(a)
# Out:
# int

# %% [markdown]
# ### Output

# %%
print("I love python") #only message
# Out:
# I love python

# %%
print(a) # only variable
# Out:
# 50

# %%
print("a")
# Out:
# a

# %%
print(f"The number is {a}") #message and variable
# Out:
# The number is 50

# %%
name = "Liji"
age = 100
print(f"My name is {name} and my age is {age}") #message and variable
# Out:
# My name is Liji and my age is 100

# %% [markdown]
# ### Comments

# %%
# anything written here wont be executed

# %% [markdown]
# ### Multiline Strings

# %%
s = """Python is a high-level, general-purpose programming language. 
Its design philosophy emphasizes code readability with the use of significant indentation. 
Its language constructs and object-oriented approach aim to help programmers write clear, logical code for small- and 
large-scale projects."""

# %%
s
# Out:
# 'Python is a high-level, general-purpose programming language. \nIts design philosophy emphasizes code readability with the use of significant indentation. \nIts language constructs and object-oriented approach aim to help programmers write clear, logical code for small- and \nlarge-scale projects.'

# %%
print(s)
# Out:
# Python is a high-level, general-purpose programming language.
# Its design philosophy emphasizes code readability with the use of significant indentation.
# Its language constructs and object-oriented approach aim to help programmers write clear, logical code for small- and
# large-scale projects.

# %% [markdown]
# ### =(assignment) and ==(comparison)

# %%
a = 1    # assigns the value. No output in this case

# %%
a
# Out:
# 1

# %%
a == 2   # comparison, returns boolean
# Out:
# False

# %% [markdown]
# ### Topics Covered
#
# * Data types
# * Variables and its assignment
# * Input
# * Output
# * Comments
# * Multiline strings
# * Assignment and comparison
