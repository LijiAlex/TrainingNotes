# %% [markdown]
# # Operators in Python

# %% [markdown]
# Operators are used to perform operations on variables and values.
#
# Few basic Python operators:
#
# * Arithmetic operators
# * Assignment operators
# * Comparison operators
# * Logical operators

# %% [markdown]
# ### Python Arithmetic Operators
# Arithmetic operators are used with numeric values to perform common mathematical operations.

# %% [markdown]
# * Addition
# * Subtraction
# * Multiplication
# * Division
# * Modulus
# * Exponentiation
# * Floor division

# %%
3 + 4    # addition
# Out:
# 7

# %%
-3 + 100
# Out:
# 97

# %%
-3 - 100   # subtraction
# Out:
# -103

# %%
x = 3
y = 4
x * y    # multiplication
# Out:
# 12

# %%
100 * x
# Out:
# 300

# %%
12 / 5 # division
# Out:
# 2.4

# %%
124 // 5  # int division and get quotient
# Out:
# 24

# %%
124 % 5 #remainder
# Out:
# 4

# %%
13 // 4
# Out:
# 3

# %%
13 / 4
# Out:
# 3.25

# %%
13 % 4
# Out:
# 1

# %%
3 ** 2  # exponential
# Out:
# 9

# %%
"hello" * 10   # repetition operator
# Out:
# 'hellohellohellohellohellohellohellohellohellohello'

# %%
"hello" + "Python"   # concatenation
# Out:
# 'helloPython'

# %% [markdown]
# ### Python Assignment Operators
# Assignment operators are used to assign values to variables.

# %%
num = 1    # simple assignment
num
# Out:
# 1

# %%
num += 1   # num = num+1    shorthand for addition to same entity
num
# Out:
# 4

# %%
num -= 100  # num=num - 100    shorthand for subtraction to same entity
num
# Out:
# -96

# %%
num *= 12    # shorthand for multiply to same entity
num
# Out:
# -1152

# %% [markdown]
# ### Python Comparison Operators
# Comparison operators are used to compare two values

# %%
num == 100   # equal to
# Out:
# False

# %%
num != 100    # not equal to
# Out:
# True

# %%
num < 100    # less than
# Out:
# True

# %%
num > 100    # greater than
# Out:
# False

# %%
num
# Out:
# -1152

# %%
num2 = 0

# %%
num = 6

# %%
num
# Out:
# 6

# %%
num < num2
# Out:
# False

# %%
num == num2
# Out:
# True

# %%
num <= num2    # either less than or equal to
# Out:
# False

# %%
num >= num2    # either greater than or equal to
# Out:
# True

# %% [markdown]
# ### Python Logical Operators
# Logical operators are used to combine conditional statements

# %%
num2 = 0

# %%
num2 == 200
# Out:
# False

# %%
num = 200

# %%
num<100
# Out:
# True

# %%
num2 == 200 and num<100   # true only if both expressions are true
# Out:
# False

# %%
num2 == 200 or num<100   # true if either of the expressions are true
# Out:
# False

# %%
not True    # negates the boolean operator
# Out:
# False

# %%
not False
# Out:
# True

# %%
num2 = 200

# %%
not num2 == 200
# Out:
# False

# %% [markdown]
# ### Topics Covered
# * Arithmetic operators
# * Assignment operators
# * Comparison operators
# * Logical operators
