# %% [markdown]
# # Sets
# * Sets are used to store multiple items in a single variable.
# * Items enclosed with curly braces {} and seperated  by comma(,).
# * A set is a collection which is unordered, unchangeable, and unindexed.
# * Items cannot be changed, but addition and deletion is allowed.
# * Duplicates are not allowed.
# * It can have any data types.

# %%
fruits = {'apple', 'banana', 'apple', 'orange', 'cherry', 'banana', 'mango'}

# %%
fruits
# Out:
# {'apple', 'banana', 'cherry', 'mango', 'orange'}

# %%
fruits[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-35-98ea8473cce4> in <module>
# ----> 1 fruits[0]
#
# TypeError: 'set' object is not subscriptable

# %% [markdown]
# ### Iteration

# %%
for fruit in fruits:
    print(fruit)

# %% [markdown]
# ### Set functions

# %% [markdown]
# https://docs.python.org/2/library/sets.html

# %%
fruits
# Out:
# {'apple', 'banana', 'cherry', 'mango', 'orange'}

# %%
fruits_copy = fruits.copy()
fruits_copy
# Out:
# {'apple', 'banana', 'cherry', 'mango', 'orange'}

# %% [markdown]
# Difference
# ![image.png](attachment:image.png)

# %%
citrus_fruits = {'orange'}
fruits.difference(citrus_fruits)
# Out:
# {'apple', 'banana', 'cherry', 'mango'}

# %%
fruits
# Out:
# {'apple', 'banana', 'cherry', 'mango', 'orange'}

# %%
fruits.difference_update(citrus_fruits)

# %%
fruits
# Out:
# {'apple', 'banana', 'cherry', 'mango'}

# %%
fruits

# %% [markdown]
# Intersection
# ![image.png](attachment:image.png)

# %%
fruits.intersection(citrus_fruits)
# Out:
# set()

# %%
fruits.intersection({'apple', 'kiwi'})
# Out:
# {'apple'}

# %%
fruits.intersection_update({'apple', 'kiwi'})

# %%
fruits
# Out:
# {'apple'}

# %%
fruits_copy
# Out:
# {'apple', 'banana', 'cherry', 'mango', 'orange'}

# %% [markdown]
# disjoint
# ![image.png](attachment:image.png)

# %%
fruits_copy.isdisjoint(fruits)
# Out:
# False

# %% [markdown]
# subset-superset
# ![image.png](attachment:image.png)

# %%
fruits.issubset(fruits_copy)
# Out:
# True

# %%
fruits_copy.issuperset(fruits)
# Out:
# True

# %% [markdown]
# Remove elements

# %%
fruits_copy.pop() # removes random element
# Out:
# 'banana'

# %%
fruits_copy
# Out:
# {'apple', 'cherry', 'orange'}

# %%
fruits_copy.remove('mango') #removes an element and throws error if not present

# %%
fruits_copy.discard('cherry') # removes the item specified else do nothing

# %%
fruits_copy
# Out:
# {'apple', 'orange'}

# %% [markdown]
# symmetric difference
# ![image.png](attachment:image.png)

# %%
fruits_copy.symmetric_difference(citrus_fruits)
# Out:
# {'apple'}

# %%
fruits_copy.symmetric_difference_update(citrus_fruits)

# %%
fruits_copy
# Out:
# {'apple'}

# %% [markdown]
# Union
# ![image.png](attachment:image.png)

# %% [markdown]
# Add Elements

# %%
fruits_copy.union(citrus_fruits)
# Out:
# {'apple', 'orange'}

# %%
fruits_copy
# Out:
# {'apple'}

# %%
fruits.add("strawberry") # adds a single item

# %%
fruits
# Out:
# {'apple', 'strawberry'}

# %%
fruits_copy.update(citrus_fruits) #updates with items of another set

# %%
fruits_copy
# Out:
# {'apple', 'orange'}
